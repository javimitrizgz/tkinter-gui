# %%
from tkinter import *
from tkinter import ttk
from tkinter.filedialog import askopenfilename
# import easygui

class StartScreen:
    def open_new_window(self):
        self.master.withdraw()
        self.new_wind_root=Toplevel(self.master)
        self.new_wind_root.geometry('400x300+100+100')
        self.new_wind_root.title("Admin Main Screen")
        self.new_wind_root.resizable(width=False,height=False)
#         pass this as master to the root level window
        new_wind=AdminMainScreen(self.new_wind_root)
    
    def __init__(self, master):
#         store the master refernce as a class variable
        self.master=master
        self.label=ttk.Label(self.master,
                             text="Catalogued")
        self.label.config(font=("Courier",30))
        self.label.grid(row=0,column=0,columnspan=2)
        
        # username related
        labelUsername=Label(self.master, 
                            text="Username",
                            fg="SeaGreen3")
        labelUsername.config(font=("Courier", 20))
        entryUsername =Entry(self.master, 
                             bd =1,
                             width=30)
        labelUsername.grid(row=5,column=0,pady=20,padx=20)
        entryUsername.grid(row=5,column=1,pady=20)
        # password related
        labelPass=Label(self.master,
                        text="Password",
                        fg="SeaGreen3")
        labelPass.config(font=("Courier", 20))
        entryPass = Entry(self.master,
                          show='*',
                          bd =1,
                          width=30)
        labelPass.grid(row=8,column=0, pady=20, padx=20)
        entryPass.grid(row=8,column=1)
        # login button
        btnContinue=Button(self.master,
                           text="Continue",
                           height=1, width=20,
                           command=lambda: self.open_new_window())
        btnContinue.grid(row=9,column=1,columnspan=2)
#         btnContinue.bind('<Button-1>',open_new_window)
    
class AdminMainScreen:
    
#     constructor for AdminMainScreen
    def __init__(self,master):
#         sore reference to master as a class variable
        self.master=master
        
        self.label=ttk.Label(self.master,text="Catalogued")
        self.label.config(font=("Courier",30))
        self.label.grid(row=0,column=1,columnspan=2, padx=(50,0))
        
#         self.label.pack(side=TOP)
#         create new model button
        self.btnCreateModel=Button(self.master,
                                   text="Create New Model",
                                   height=1, width=20,
                                   command=lambda: self.open_create_new_model_screen()) #launch create new model screen
        self.btnCreateModel.grid(row=2,column=2,columnspan=3,padx=(130, 10), pady=(30,0))
#         self.btnCreateModel.pack()
#         add update model button
        self.btnUpdateModel=Button(self.master,
                                   text="Update Model",
                                   height=1, width=20,
                                   command=lambda: self.open_update_model_screen())
        self.btnUpdateModel.grid(row=3,column=2,columnspan=3,padx=(130, 10), pady=(30,0))
#         self.btnUpdateModel.pack()
#         create delete model button
        self.btnDeleteModel=Button(self.master,
                                   text="Delete Model",
                                   height=1, width=20,
                                   command=lambda: self.open_delete_model_screen())
        self.btnDeleteModel.grid(row=6,column=2,columnspan=3,padx=(130, 10), pady=(30,0))
#         self.btnDeleteModel.pack()

#         add rename model button
        self.btnRenameModel=Button(self.master,
                                   text="Rename Model",
                                   height=1, width=20,
                                   command=lambda: self.open_rename_model_screen())
        self.btnRenameModel.grid(row=6,column=2,columnspan=3,padx=(130, 10), pady=(30,0))
#         self.btnRenameModel.pack()
#         add Generate video button
        self.btnGenerateVideo=Button(master,
                                   text="Generate Video",
                                   height=1, width=20,
                                   command=lambda: self.open_generate_video_screen()) #launch generate videoo screen
        self.btnGenerateVideo.grid(row=7,column=2,columnspan=3,padx=(130, 10), pady=(30,0))
#         self.btnGenerateVideo.pack()
    
    
    def open_create_new_model_screen(self):
#         self.master.withdraw()
        self.root_for_create_new_model_sceen=Toplevel(self.master)
        self.root_for_create_new_model_sceen.geometry('400x300+100+100')
        self.root_for_create_new_model_sceen.title("Create New Model")
        self.root_for_create_new_model_sceen.resizable(width=False,height=False)
#         open the window by providing it the above created ref as its master
        create_vid_screen=CreateNewModelScreen(self.root_for_create_new_model_sceen)
    
    def open_update_model_screen(self):
#         self.master.withdraw()
        self.root_for_update_model_window=Toplevel(self.master)
        self.root_for_update_model_window.geometry('400x300+100+100')
        self.root_for_update_model_window.title("Update Existing Model")
        self.root_for_update_model_window.resizable(width=False,height=False)
#         open the window by providing it the above created ref as its master
        update_window=CreateNewModelScreen(self.root_for_update_model_window)
        
    def open_delete_model_screen(self):
#         self.master.withdraw()
        self.root_for_delete_model_window=Toplevel(self.master)
        self.root_for_delete_model_window.geometry('400x300+100+100')
        self.root_for_delete_model_window.title("Delete Existing Model")
        self.root_for_delete_model_window.resizable(width=False,height=False)
        update_window=CreateNewModelScreen(self.root_for_delete_model_window)
        
    def open_rename_model_screen(self):
#         self.master.withdraw()
        self.root_for_rename_model_window=Toplevel(self.master)
        self.root_for_rename_model_window.geometry('400x300+100+100')
        self.root_for_rename_model_window.title("Rename Model")
        self.root_for_rename_model_window.resizable(width=False,height=False)
        update_window=RenameModelScreen(self.root_for_rename_model_window)

    def open_generate_video_screen(self):
#         self.master.withdraw()
        self.root_for_generate_vid_screen=Toplevel(self.master)
        self.root_for_generate_vid_screen.geometry('400x350+100+100')
        self.root_for_generate_vid_screen.title("Generate Subject's Video")
        self.root_for_generate_vid_screen.resizable(width=False,height=False)
        gen_vid_screen=GenerateVideoScreen(self.root_for_generate_vid_screen)
    
    
class CreateNewModelScreen:
    
    def __init__(self,master):
        
        self.master=master
        
        self.label=ttk.Label(self.master,text="Catalogued")
        self.label.config(font=("Courier",30))
        self.label.grid(row=0,column=0,columnspan=2)
        
         # model name related
        self.label=ttk.Label(self.master,
                             text="Model Name")
        self.label.config(font=("Courier",15))
        self.label.grid(row=1,column=0,columnspan=1,padx=(0, 10), pady=(30,0))
        entrySubject =Entry(self.master,
                            bd =1,
                            width=30)
        entrySubject.grid(row=1,column=1,pady=(30,0))
        
#         add create model button
        self.btnCreate=Button(self.master,
                                   text="Create Model",
                                   height=1, width=20,
                                   command=lambda: print('creating new model'))
        self.btnCreate.grid(row=2,column=1,columnspan=2, pady=(30,0))

class UpdateModelScreen:
    
    def __init__(self,master):
#         store reference to master as class var
        self.master=master
        
        self.label=ttk.Label(self.master,text="Catalogued")
        self.label.config(font=("Courier",30))
        self.label.grid(row=0,column=0,columnspan=2)
        
#        model name related
        self.label=ttk.Label(self.master,
                             text="Model Name")
        self.label.config(font=("Courier",15))
        self.label.grid(row=0,column=0,columnspan=1, padx=(10,0), pady=(30,0))
        entrySubject =Entry(self.master,
                            bd =1,
                            width=30)
        entrySubject.grid(row=0,column=1)
        
#         add update model button
        self.btnUpdateModel=Button(self.master,
                                   text="Update Model",
                                   height=1, width=20,
                                   command=lambda: print('updating the model'))
        self.btnUpdateModel.grid(row=1,column=1,columnspan=2, pady=(30,0))
        
        
class DeleteModelScreen:
    def __init__(self,master):
        
        self.master=master
        
        self.label=ttk.Label(self.master,text="Catalogued")
        self.label.config(font=("Courier",30))
        self.label.grid(row=0,column=0,columnspan=2)
        
#         model name related
        self.label=ttk.Label(self.master,
                             text="Model Name")
        self.label.config(font=("Courier",15))
        self.label.grid(row=0,column=0,columnspan=1, padx=(10,0), pady=(30,0))
        entrySubject =Entry(self.master,
                            bd =1,
                            width=30)
        entrySubject.grid(row=0,column=1, pady=(30,0))
        
#         add delete the model button
        self.btnDelete=Button(self.master,
                                   text="Delete the Model",
                                   height=1, width=20,
                                   command=lambda: print('Deleting the chosen model'))
        self.btnDelete.grid(row=1,column=1,columnspan=2, pady=(30,0))
        

class RenameModelScreen:
     def __init__(self,master):
#         store reference to master as class var
        self.master=master
        
        self.label=ttk.Label(self.master,text="Catalogued")
        self.label.config(font=("Courier",30))
        self.label.grid(row=0,column=0,columnspan=2)
        
#        model name related
        self.old_model_name=ttk.Label(self.master,
                             text="Existing Name")
        self.old_model_name.config(font=("Courier",15))
        self.old_model_name.grid(row=1,column=0,columnspan=1, padx=(10,0), pady=(30,0))
        self.entry_new_model_name =Entry(self.master,
                            bd =1,
                            width=30)
        self.entry_new_model_name.grid(row=1,column=1, pady=(30,0))
        
#         new model name related
        self.new_model_name_label=ttk.Label(self.master,
                             text="New Model Name")
        self.new_model_name_label.config(font=("Courier",15))
        self.new_model_name_label.grid(row=2,column=0,columnspan=1, padx=(10,0), pady=(30,0))
        self.entry_new_name=Entry(self.master,
                            bd =1,
                            width=30)
        self.entry_new_name.grid(row=2,column=1, pady=(30,0))
        
#         add the rename model button
        self.btnRename=Button(self.master,
                                   text="Rename the Model",
                                   height=1, width=20,
                                   command=lambda: print('Renaming the chosen model'))
        self.btnRename.grid(row=3,column=1,columnspan=2, pady=(30,0))
        
class GenerateVideoScreen:
    def __init__(self,master):
        
#         variable for storing path of the model file
#         which will be chosoen at runtime by user
        self.chosen_model_file_path=None
        
        self.master=master
        
        self.label=ttk.Label(self.master,text="Catalogued")
        self.label.config(font=("Courier",30))
        self.label.grid(row=0,column=0,columnspan=2)
        
#         subject label related
        self.label=ttk.Label(self.master,
                             text="Subject Label")
        self.label.config(font=("Courier",15))
        self.label.grid(row=1,column=0,columnspan=1, padx=(10,0), pady=(30,0))
        entrySubject =Entry(self.master,
                            bd =1,
                            width=30)
        entrySubject.grid(row=1,column=1, pady=(30,0))
        
#         start time
        self.label=ttk.Label(self.master,
                             text="Start time")
        self.label.config(font=("Courier",15))
        self.label.grid(row=2,column=0,columnspan=1, padx=(10,0), pady=(30,0))
        entrySubject =Entry(self.master,
                            bd =1,
                            width=30)
        entrySubject.grid(row=2,column=1, pady=(30,0))
        
#         end time
        self.label=ttk.Label(self.master,
                             text="End time")
        self.label.config(font=("Courier",15))
        self.label.grid(row=3,column=0,columnspan=1, padx=(10,0), pady=(30,0))
        entrySubject =Entry(self.master,
                            bd =1,
                            width=30)
        entrySubject.grid(row=3,column=1, pady=(30,0))
        
#         model name
#         self.label=ttk.Label(self.master,
#                              text="Model name")
#         self.label.config(font=("Courier",15))
#         self.label.grid(row=4,column=0,columnspan=1, padx=(10,0), pady=(30,0))
#         entrySubject =Entry(self.master,
#                             bd =1,
#                             width=30)
#         entrySubject.grid(row=4,column=1, pady=(30,0))
        
#         add file picker button
        self.btnGenerateVideo=Button(self.master,
                                   text="Pick Model File",
                                   height=1, width=20,
                                   command=lambda: self.pick_model_file())
        self.btnGenerateVideo.grid(row=4,column=1,columnspan=2, pady=(20,0))

        
#         add Generate video button
        self.btnGenerateVideo=Button(self.master,
                                   text="Generate Subject's Video",
                                   height=1, width=20,
                                   command=lambda: print("Generating footage of the subject"))
        self.btnGenerateVideo.grid(row=5,column=1,columnspan=2, pady=(20,0))

    def pick_model_file(self):
        ftypes = [('yml model file',"*.yml")]
        ttl  = "Pick model file"
        dir1 = 'C:\\'
        fileName = askopenfilename(filetypes = ftypes, initialdir = dir1, title = ttl)
        self.chosen_model_file_path=fileName
        print(self.chosen_model_file_path)  #prints the path+name of the chosen file 
        
        
def main():
    root = Tk()
    root.geometry('400x300')
    root.resizable(width=False,height=False)
    app=StartScreen(root)
    root.mainloop()

if __name__=="__main__": main()
# Out:
# creating new model
#
#
# Generating footage of the subject
